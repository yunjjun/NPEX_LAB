# %%
cd /content
# Out:
# /content

# %%
# !git clone https://github.com/khanrc/pt.darts.git
# Out:
# Cloning into 'pt.darts'...
# remote: Enumerating objects: 150, done.
# remote: Total 150 (delta 0), reused 0 (delta 0), pack-reused 150
# Receiving objects: 100% (150/150), 11.63 MiB | 6.51 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %% [markdown]
# MNIST를 5000장만 사용하도록 코드를 수정해보자.
#
# 또한,
#
# !pip install tensorboardX 를 통해 tensorboardX를 install하거나,
#
# from tensorboardX import SummaryWriter 를
#
# from torch.utils.tensorboard import SummaryWriter 로 수정하자.

# %%
cd /content/pt.darts
# Out:
# /content/pt.darts

# %%
# !pwd
# %env PYTHONPATH=/content/pt.darts
# !python search.py --name=mnist  --dataset=mnist  --layers=3 --epochs=3
# Out:
# /content/pt.darts
# env: PYTHONPATH=/content/pt.darts
# 2020-07-02 04:52:06.773391: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 07/02 04:52:08 AM |
# 07/02 04:52:08 AM | Parameters:
# 07/02 04:52:08 AM | ALPHA_LR=0.0003
# 07/02 04:52:08 AM | ALPHA_WEIGHT_DECAY=0.001
# 07/02 04:52:08 AM | BATCH_SIZE=64
# 07/02 04:52:08 AM | DATA_PATH=./data/
# 07/02 04:52:08 AM | DATASET=mnist
# 07/02 04:52:08 AM | EPOCHS=3
# 07/02 04:52:08 AM | GPUS=[0]
# 07/02 04:52:08 AM | INIT_CHANNELS=16
# 07/02 04:52:08 AM | LAYERS=3
# 07/02 04:52:08 AM | NAME=mnist
# 07/02 04:52:08 AM | PATH=searchs/mnist
# 07/02 04:52:08 AM | PLOT_PATH=searchs/mnist/plots
# 07/02 04:52:08 AM | PRINT_FREQ=50
# 07/02 04:52:08 AM | SEED=2
# 07/02 04:52:08 AM | W_GRAD_CLIP=5.0
# 07/02 04:52:08 AM | W_LR=0.025
# 07/02 04:52:08 AM | W_LR_MIN=0.001
# 07/02 04:52:08 AM | W_MOMENTUM=0.9
# 07/02 04:52:08 AM | W_WEIGHT_DECAY=0.0003
# ...

# %% [markdown]
# ## 결과 Normal Cell

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 결과 Reduction Cell

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
